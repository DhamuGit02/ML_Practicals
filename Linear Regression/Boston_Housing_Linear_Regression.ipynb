# %%
import pandas as pd
import numpy as np

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv("./housing.csv", header=None, delimiter=r"\s+", names=column_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.shape
# Out:
# (505, 1)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 506, dtype: bool

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.tail()
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df["CRIM"].isnull().sum()
# Out:
# 0

# %%
plt.boxplot(df["CRIM"].values)
plt.show()

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
corr = df.corr()
print(corr.shape)
# Out:
# (14, 14)

# %%
corr_mat = np.array(corr)

# %%
neg_corr_dict = dict()
for col in df.columns:
  neg_corr_dict.update({col:0})
neg_corr_dict
# Out:
# {'CRIM': 0,
#  'ZN': 0,
#  'INDUS': 0,
#  'CHAS': 0,
#  'NOX': 0,
#  'RM': 0,
#  'AGE': 0,
#  'DIS': 0,
#  'RAD': 0,
#  'TAX': 0,
#  'PTRATIO': 0,
#  'B': 0,
#  'LSTAT': 0,
#  'MEDV': 0}

# %%
for i in range(14):
  for j in range(14):
    if(corr_mat[i][j] < 0):
      neg_corr_dict.update({column_names[i]:neg_corr_dict.get(column_names[i]) + 1})
neg_corr_dict
# Out:
# {'CRIM': 6,
#  'ZN': 9,
#  'INDUS': 5,
#  'CHAS': 7,
#  'NOX': 5,
#  'RM': 8,
#  'AGE': 5,
#  'DIS': 9,
#  'RAD': 6,
#  'TAX': 6,
#  'PTRATIO': 6,
#  'B': 8,
#  'LSTAT': 6,
#  'MEDV': 8}

# %%
new_df = df.drop(["CRIM", "ZN", "CHAS", "B"], axis=1)
new_df.corr()
# Out:
#             INDUS       NOX        RM       AGE       DIS       RAD       TAX  \
# INDUS    1.000000  0.763651 -0.391676  0.644779 -0.708027  0.595129  0.720760
# NOX      0.763651  1.000000 -0.302188  0.731470 -0.769230  0.611441  0.668023
# RM      -0.391676 -0.302188  1.000000 -0.240265  0.205246 -0.209847 -0.292048
# AGE      0.644779  0.731470 -0.240265  1.000000 -0.747881  0.456022  0.506456
# DIS     -0.708027 -0.769230  0.205246 -0.747881  1.000000 -0.494588 -0.534432
# RAD      0.595129  0.611441 -0.209847  0.456022 -0.494588  1.000000  0.910228
# TAX      0.720760  0.668023 -0.292048  0.506456 -0.534432  0.910228  1.000000
# PTRATIO  0.383248  0.188933 -0.355501  0.261515 -0.232471  0.464741  0.460853
# LSTAT    0.603800  0.590879 -0.613808  0.602339 -0.496996  0.488676  0.543993
# MEDV    -0.483725 -0.427321  0.695360 -0.376955  0.249929 -0.381626 -0.468536
#
#           PTRATIO     LSTAT      MEDV
# INDUS    0.383248  0.603800 -0.483725
# ...

# %%
X = new_df.drop("NOX", axis=1).values
Y = new_df["NOX"].values
X, Y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=45)

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lin_model.score(X_test, Y_test)
# Out:
# 0.7749290807675814

# %%
Y_predict = lin_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(Y_test, Y_predict)
# Out:
# 0.0768918997765351
